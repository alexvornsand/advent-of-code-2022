# %%
import re

log = open('input.txt', 'r').read().split('\n')[:-1]

# %%
def makeFileSpace(log, partTwo=False):

    def mapLogToTree(log):
        tree = {'/':{}}
        lineage = ['/']
        for line in log:
            if line[0:4] == '$ cd':
                if line[5:] == '/':
                    env = tree['/']
                    lineage = ['/']
                elif line[5:] == '..':
                    env = tree
                    lineage.pop(-1)
                    for directory in lineage:
                        env = env[directory]
                else:
                    env = env[line[5:]]
                    lineage.append(line[5:])
            elif line[0:4] == '$ ls':
                pass
            elif line[0:3] == 'dir':
                env[line[4:]] = {}
            else:
                fileInfo = re.search(r'(\d+)\s(.*)', line)
                size = int(fileInfo.groups()[0])
                name = fileInfo.groups()[1]
                env[name] = size
        return(tree)

    def navigateTree(tree, lineage=''):
        dirDict = {}
        for key in tree.keys():
            if lineage == '':
                dictName = key
            else:
                dictName = lineage + '-' + key
            dirDict[dictName] = 0
            if type(tree[key]) is dict:
                for sub in tree[key].keys():
                    if type(tree[key][sub]) is int:
                        dirDict[dictName] += tree[key][sub]
                    else:
                        subDict = navigateTree({sub: tree[key][sub]}, dictName)
                        dirDict[dictName] += subDict[dictName + '-' + sub]
                        dirDict.update(subDict)
        return(dirDict)      

    tree = mapLogToTree(log)
    dirs = navigateTree(tree)
    
    if partTwo is False:
        return(sum([dir for dir in dirs.values() if dir <= 100000]))
    else:
        return(min([dir for dir in dirs.values() if dir >= (30000000 + dirs['/'] - 70000000)]))

# %%
makeFileSpace(log)
# Out:
# 1444896

# %%
makeFileSpace(log, True)
# Out:
# 404395

# %%
navigateTree(tree, '')
# Out:
# {'/': 40389918,
#  '/-bnl': 4283758,
#  '/-bnl-dhw': 237421,
#  '/-bnl-dmpsnhdh': 2089974,
#  '/-bnl-dmpsnhdh-chf': 573029,
#  '/-bnl-dmpsnhdh-chf-zfgznbz': 350983,
#  '/-bnl-dmpsnhdh-mjpbhjm': 1375812,
#  '/-bnl-dmpsnhdh-mjpbhjm-crf': 497521,
#  '/-bnl-dmpsnhdh-mjpbhjm-hqnj': 339702,
#  '/-bnl-dmpsnhdh-mjpbhjm-lmw': 50307,
#  '/-bnl-dmpsnhdh-zwhpwp': 141133,
#  '/-bnl-lmw': 779209,
#  '/-bnl-lmw-dvv': 216597,
#  '/-bnl-vgbqbrst': 1177154,
#  '/-bnl-vgbqbrst-jbdtpnw': 27543,
#  '/-bnl-vgbqbrst-rflp': 221045,
#  '/-bnl-vgbqbrst-twpq': 92924,
#  '/-bnl-vgbqbrst-twpq-rlbsdj': 56078,
#  '/-dmpsnhdh': 3192609,
#  '/-dmpsnhdh-fnpwwhtj': 514966,
#  '/-dmpsnhdh-fnpwwhtj-cgp': 514966,
#  '/-dmpsnhdh-lmw': 2482179,
#  '/-dmpsnhdh-lmw-bfbv': 92667,
#  '/-dmpsnhdh-lmw-rrqjwpm': 117064,
#  '/-dmpsnhdh-lmw-sngm': 2215519,
#  '/-dmpsnhdh-lmw-sngm-lmw': 177203,
#  '/-dmpsnhdh-lmw-sngm-lmw-glwr': 144719,
#  '/-dmpsnhdh-lmw-sngm-lqd': 925297,
#  '/-dmpsnhdh-lmw-sngm-lqd-jnjqmvg': 104947,
#  '/-dmpsnhdh-lmw-sngm-lqd-lmw': 389245,
#  '/-dmpsnhdh-lmw-sngm-szn': 197974,
#  '/-fcnqg': 769565,
#  '/-jvwtm': 8509877,
#  '/-jvwtm-dmpsnhdh': 1375783,
#  '/-jvwtm-dmpsnhdh-llhp': 180255,
#  '/-jvwtm-dmpsnhdh-mnsbh': 267627,
#  '/-jvwtm-dmpsnhdh-mpplsfjp': 476965,
#  '/-jvwtm-dmpsnhdh-mpplsfjp-bnl': 243223,
#  '/-jvwtm-tlr': 1219467,
#  '/-jvwtm-tlr-vcsngm': 36434,
#  '/-jvwtm-tlr-wndmt': 1183033,
#  '/-jvwtm-tlr-wndmt-fvmtfcqd': 237025,
#  '/-jvwtm-tlr-wndmt-nvdb': 338644,
#  '/-jvwtm-tlr-wndmt-nwqqgl': 337354,
#  '/-jvwtm-tlr-wndmt-nwqqgl-cljbrh': 133820,
#  '/-jvwtm-tlr-wndmt-sbspgnpm': 270010,
#  '/-jvwtm-twpq': 1226742,
#  '/-jvwtm-twpq-dmpsnhdh': 575779,
#  '/-jvwtm-twpq-hbchdjjp': 301016,
#  '/-jvwtm-wbgcsw': 3609909,
#  '/-jvwtm-wbgcsw-bnl': 1615223,
#  '/-jvwtm-wbgcsw-bnl-fbbr': 84414,
#  '/-jvwtm-wbgcsw-bnl-mzfrdl': 625824,
#  '/-jvwtm-wbgcsw-bnl-mzfrdl-cjdptqgh': 159918,
#  '/-jvwtm-wbgcsw-bnl-mzfrdl-hwdnrqns': 254432,
#  '/-jvwtm-wbgcsw-bnl-mzfrdl-hwdnrqns-dmpsnhdh': 254432,
#  '/-jvwtm-wbgcsw-bnl-mzfrdl-prq': 75827,
#  '/-jvwtm-wbgcsw-bnl-tqgrdz': 251475,
#  '/-jvwtm-wbgcsw-bnl-ztrnq': 387873,
#  '/-jvwtm-wbgcsw-bqq': 202201,
#  '/-jvwtm-wbgcsw-ctnlpgt': 269484,
#  '/-jvwtm-wbgcsw-hbqm': 117203,
#  '/-jvwtm-wbgcsw-zqmjwsgz': 146194,
#  '/-jvwtm-wbgcsw-zwwphs': 209587,
#  '/-jvwtm-zjmldjdh': 1030017,
#  '/-jvwtm-zjmldjdh-cdq': 289173,
#  '/-jvwtm-zjmldjdh-mdclfbs': 404395,
#  '/-jvwtm-zjmldjdh-mdclfbs-hpdgt': 107421,
#  '/-jvwtm-zjmldjdh-tfc': 204406,
#  '/-ldztz': 978231,
#  '/-ldztz-dmpsnhdh': 524132,
#  '/-ldztz-lbqgz': 171931,
#  '/-ldztz-znrnj': 153738,
#  '/-lmmw': 1507116,
#  '/-lmmw-bqqnsfdj': 1008403,
#  '/-lmmw-bqqnsfdj-bnl': 808144,
#  '/-lmmw-bqqnsfdj-bnl-lmw': 156532,
#  '/-lmmw-bqqnsfdj-bnl-lmw-sfj': 156532,
#  '/-lmmw-bqqnsfdj-bnl-nqw': 59928,
#  '/-lmmw-bqqnsfdj-tlnbvhdl': 183301,
#  '/-lmmw-rlpcqtzg': 258638,
#  '/-wthvqw': 224501,
#  '/-zpdnprb': 20646114,
#  '/-zpdnprb-bnl': 520152,
#  '/-zpdnprb-bnl-pnzmp': 236287,
#  '/-zpdnprb-bnl-pnzmp-btbtlrs': 107651,
#  '/-zpdnprb-ffg': 57918,
#  '/-zpdnprb-jljlwpsv': 346425,
#  '/-zpdnprb-rrqjwpm': 9290252,
#  '/-zpdnprb-rrqjwpm-bftw': 1561114,
#  '/-zpdnprb-rrqjwpm-bftw-brl': 297937,
#  '/-zpdnprb-rrqjwpm-bftw-lmw': 166695,
#  '/-zpdnprb-rrqjwpm-bftw-rrqjwpm': 198762,
#  '/-zpdnprb-rrqjwpm-bftw-twpq': 141835,
#  '/-zpdnprb-rrqjwpm-bftw-vnfhb': 128626,
#  '/-zpdnprb-rrqjwpm-bftw-wcldzp': 285142,
#  '/-zpdnprb-rrqjwpm-bftw-wcldzp-ncq': 133331,
#  '/-zpdnprb-rrqjwpm-bftw-wcldzp-ncq-wrtw': 133331,
#  '/-zpdnprb-rrqjwpm-bftw-wcldzp-twpq': 151811,
#  '/-zpdnprb-rrqjwpm-ccsfws': 100548,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh': 7050334,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw': 2864435,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl': 2423491,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-lmw': 233655,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm': 2189836,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm-hsvnmlp': 264517,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm-nsch': 714999,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm-nsch-lmw': 69572,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm-nsch-sgjsg': 38856,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm-qlgg': 276013,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-bgl-rrqjwpm-twpq': 370831,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-lmw-jqthwzj': 128200,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-mfms': 641673,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-mfms-rmwtvjt': 74490,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl': 1510920,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-cswvftzs': 545967,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-cswvftzs-dchqnbns': 94111,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-cswvftzs-smf': 451856,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-cswvftzs-smf-dlnsgvl': 156473,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-cswvftzs-smf-dlnsgvl-dsz': 156473,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-cswvftzs-smf-zglt': 295383,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-jtvtg': 260673,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-lmw': 8097,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-tnctbjr': 368045,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-tnctbjr-gzrcqr': 117215,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-tnctbjr-gzrcqr-fnzgsnv': 117215,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-pjbjgbcl-tqsrfhdr': 96381,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-wzqbwr': 1602652,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-wzqbwr-dpbcgfdr': 1107794,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-wzqbwr-dpbcgfdr-jvn': 350765,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-wzqbwr-dpbcgfdr-wzpbbbhm': 143534,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-wzqbwr-swp': 131295,
#  '/-zpdnprb-rrqjwpm-wwfgbzqh-wzqbwr-zhj': 200002,
#  '/-zpdnprb-twpq': 5296583,
#  '/-zpdnprb-twpq-bppvlwqs': 474285,
#  '/-zpdnprb-twpq-bvh': 66958,
#  '/-zpdnprb-twpq-bvh-lmw': 66958,
#  '/-zpdnprb-twpq-rmcdr': 3617232,
#  '/-zpdnprb-twpq-rmcdr-dmpsnhdh': 515068,
#  '/-zpdnprb-twpq-rmcdr-dmpsnhdh-rrqjwpm': 326594,
#  '/-zpdnprb-twpq-rmcdr-dmpsnhdh-rrqjwpm-bnl': 245600,
#  '/-zpdnprb-twpq-rmcdr-dmpsnhdh-rrqjwpm-lmw': 73396,
#  '/-zpdnprb-twpq-rmcdr-pmrdhrth': 351685,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh': 2227079,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh-lmw': 1438328,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh-lmw-bbbll': 635197,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh-lmw-mlz': 115167,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh-qfrvdm': 284564,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh-rcg': 116435,
#  '/-zpdnprb-twpq-rmcdr-zbmcrvbh-rcg-sqzjz': 116435,
#  '/-zpdnprb-twpq-tdn': 764730,
#  '/-zpdnprb-twpq-tdn-pstpclp': 354281,
#  '/-zpdnprb-twpq-wwtwnvh': 371148,
#  '/-zpdnprb-vlgsrtm': 4922703,
#  '/-zpdnprb-vlgsrtm-dmpsnhdh': 459053,
#  '/-zpdnprb-vlgsrtm-dmpsnhdh-lltnrdtv': 270424,
#  '/-zpdnprb-vlgsrtm-dmpsnhdh-scthsg': 188629,
#  '/-zpdnprb-vlgsrtm-dmpsnhdh-scthsg-rrqjwpm': 188629,
#  '/-zpdnprb-vlgsrtm-fjsglr': 253602,
#  '/-zpdnprb-vlgsrtm-fjsglr-pnsjwfzc': 113848,
#  '/-zpdnprb-vlgsrtm-lmw': 1188146,
#  '/-zpdnprb-vlgsrtm-lmw-ffhcf': 40478,
#  '/-zpdnprb-vlgsrtm-lmw-jpgqspqw': 22181,
#  '/-zpdnprb-vlgsrtm-lmw-pfsjwmbc': 225892,
#  '/-zpdnprb-vlgsrtm-lmw-pfsjwmbc-bcvchw': 225892,
#  '/-zpdnprb-vlgsrtm-lqgrft': 1469401,
#  '/-zpdnprb-vlgsrtm-lqgrft-rrqjwpm': 57839,
#  '/-zpdnprb-vlgsrtm-lqgrft-twpq': 1411562,
#  '/-zpdnprb-vlgsrtm-lqgrft-twpq-lmw': 521518,
#  '/-zpdnprb-vlgsrtm-lqgrft-twpq-lmw-lmw': 139640,
#  '/-zpdnprb-vlgsrtm-lqgrft-twpq-lmw-lngbszqm': 381878,
#  '/-zpdnprb-vlgsrtm-lqgrft-twpq-mhgqt': 208165,
#  '/-zpdnprb-vlgsrtm-rmdp': 337538,
#  '/-zpdnprb-vlgsrtm-rmdp-bqn': 75628,
#  '/-zpdnprb-vlgsrtm-vgjzqjpq': 273695,
#  '/-zpdnprb-vlgsrtm-vgjzqjpq-bnl': 25911,
#  '/-zpdnprb-vlgsrtm-vgjzqjpq-wpfw': 247784,
#  '/-zpdnprb-vlgsrtm-ztnqnfnq': 356707,
#  '/-zpdnprb-vlgsrtm-ztnqnfnq-dtpzsrfc': 142652}

# %%
tree
# Out:
# {'/': {'bnl': {'dhw': {'vccwmhl': 237421},
#    'dmpsnhdh': {'chf': {'lmw.wmp': 4679,
#      'wwnfv.qqr': 217367,
#      'zfgznbz': {'cnj.gdn': 179409, 'vglqg': 171574}},
#     'mjpbhjm': {'crf': {'dltmqht': 32183,
#       'frqqdsr.hbf': 240428,
#       'sgtnrvrt': 224910},
#      'hqnj': {'cgstb': 261723, 'dmpsnhdh.cmd': 77979},
#      'lmw': {'fcqrwd': 50307},
#      'lmw.rwr': 18783,
#      'twpq': 302608,
#      'vqczlg': 166891},
#     'zwhpwp': {'gdngm.mps': 141133}},
#    'lmw': {'dvv': {'gmlmbrrw.wdm': 114536, 'lmw': 102061},
#     'jmqgrh.dlz': 267473,
#     'rrqjwpm': 295139},
#    'vgbqbrst': {'dmpsnhdh.bgl': 105102,
#     'gmwgjf.fzz': 269054,
#     'jbdtpnw': {'cjvvmzp': 27543},
#     'jzsjvgl': 245266,
#     'lmw.gtb': 216220,
#     'rflp': {'frqqdsr.hbf': 137601, 'rrqjwpm': 83444},
#     'twpq': {'rlbsdj': {'bvndq': 56078}, 'tnrqzjdd': 36846}}},
#   'dmpsnhdh': {'fnpwwhtj': {'cgp': {'hjpmqrq': 81938,
#      'jvszf': 281971,
#      'wmr.bnf': 151057}},
#    'lmw': {'bfbv': {'qrrttb.jgp': 92667},
#     'pbb.zln': 56929,
#     'rrqjwpm': {'cqljn.zqw': 25739, 'dncdssn.hdr': 91325},
#     'sngm': {'jgrj': 282163,
#      'lmw': {'dncdssn.hdr': 32484, 'glwr': {'frqqdsr.hbf': 144719}},
#      'lmw.dff': 237524,
#      'lmw.ntg': 153497,
#      'lqd': {'dncdssn.hdr': 231401,
#       'jnjqmvg': {'trpsrfjz.brg': 104947},
#       'lmw': {'rrqjwpm.nnv': 230298, 'wfv.qrb': 158947},
#       'rrqjwpm': 199704},
#      'szn': {'frqqdsr.hbf': 197974},
#      'tvpvc.qpr': 143535,
#      'vbfgh': 98326}},
#    'mgjpsvl.jlh': 9090,
#    'pbb.zln': 186374},
#   'dncdssn.hdr': 272080,
#   'fcnqg': {'dncdssn.hdr': 251609, 'jdjmftqs': 289497, 'qbmthcq': 228459},
#   'hjpmqrq': 6067,
#   'jvwtm': {'dmpsnhdh': {'bnl': 247567,
#     'bnl.wdm': 102471,
#     'fhqvp.hfm': 80054,
#     'llhp': {'dmpsnhdh': 180255},
#     'mnsbh': {'dmpsnhdh': 267627},
#     'mpplsfjp': {'bnl': {'fcqrwd': 243223}, 'tcnpvqc.tdr': 233742},
#     'mtvl.lmp': 20844},
#    'pbb.zln': 47959,
#    'tlr': {'vcsngm': {'czs.dnv': 36434},
#     'wndmt': {'fvmtfcqd': {'nzttjt.rzh': 237025},
#      'nvdb': {'dnrqwqtp.vfc': 235328, 'rhblt.mfz': 51984, 'rjhvhw': 51332},
#      'nwqqgl': {'cjghw': 203534, 'cljbrh': {'lmw.dnd': 133820}},
#      'sbspgnpm': {'hjpmqrq': 270010}}},
#    'twpq': {'dmpsnhdh': {'dncdssn.hdr': 251490,
#      'hjpmqrq': 222231,
#      'pbb.zln': 102058},
#     'hbchdjjp': {'dprrmd.qcd': 70058, 'tsdbl.bnq': 230958},
#     'hjpmqrq': 247649,
#     'rrqjwpm': 29891,
#     'twpq.crb': 72407},
#    'wbgcsw': {'bhtfcf': 292028,
#     'bnl': {'fbbr': {'mjbw.dhs': 84414},
#      'frqqdsr.hbf': 240500,
#      'mzfrdl': {'bccwgn': 135647,
#       'cjdptqgh': {'mdgl.drz': 147946, 'pbb.zln': 11972},
#       'hwdnrqns': {'dmpsnhdh': {'phthmn': 254432}},
#       'prq': {'dmpsnhdh.rtl': 75827}},
#      'srqlww.mcj': 25137,
#      'tqgrdz': {'bjwnll.rlw': 251475},
#      'ztrnq': {'bnl.dtr': 208497, 'gqnbswcj.hht': 179376}},
#     'bqq': {'bnl.lbm': 202201},
#     'ctnlpgt': {'vsfvzrpr': 269484},
#     'hblhfvwj': 247888,
#     'hbqm': {'bvnfz': 74455, 'pbb.zln': 42748},
#     'pbb.zln': 277949,
#     'rrqjwpm': 106225,
#     'ssqpmlfb.gwm': 125927,
#     'zqmjwsgz': {'pbb.zln': 146194},
#     'zwwphs': {'mtbzd.nwb': 209587}},
#    'zjmldjdh': {'cdq': {'twpq.mrn': 289173},
#     'mdclfbs': {'bnl.jwf': 64639,
#      'hpdgt': {'fcqrwd': 52760, 'tzgt.hvh': 54661},
#      'hznfj.nmj': 72868,
#      'lmw.bfz': 159467},
#     'tfc': {'bwntlh': 185481, 'fcqrwd': 18925},
#     'wrm': 132043}},
#   'ldztz': {'bwz.fcz': 128430,
#    'dmpsnhdh': {'dncdssn.hdr': 238193, 'hwfngq.dpw': 285939},
#    'lbqgz': {'vgrp': 171931},
#    'znrnj': {'vmwwbjqd': 153738}},
#   'lmmw': {'bqqnsfdj': {'bnl': {'bnl.fqp': 33357,
#      'bnl.vbs': 151237,
#      'dmpsnhdh.hwz': 40294,
#      'dncdssn.hdr': 76455,
#      'hjpmqrq': 290341,
#      'lmw': {'sfj': {'fcqrwd': 156532}},
#      'nqw': {'dncdssn.hdr': 59928}},
#     'hjpmqrq': 2251,
#     'rrqjwpm': 14707,
#     'tlnbvhdl': {'hjpmqrq': 183301}},
#    'fcqrwd': 163303,
#    'frqqdsr.hbf': 43453,
#    'hjpmqrq': 33319,
#    'rlpcqtzg': {'dqt.mlc': 258638}},
#   'wthvqw': {'pbb.zln': 224501},
#   'zpdnprb': {'bnl': {'hjgjf': 124009,
#     'hjpmqrq': 74860,
#     'lrdl.swf': 84996,
#     'pnzmp': {'btbtlrs': {'hhzbwd.wzj': 107651}, 'nfzf': 128636}},
#    'ffg': {'jwzbs.tnt': 57918},
#    'jljlwpsv': {'dmpsnhdh.nnb': 188175, 'fcqrwd': 46693, 'pbb.zln': 111557},
#    'lrzc.lhj': 212081,
#    'rrqjwpm': {'bftw': {'brl': {'wspcnp': 297937},
#      'crs': 167154,
#      'lmw': {'mcjql.jrv': 166695},
#      'rrqjwpm': {'mwn': 198762},
#      'twpq': {'jlwf.hcd': 141835},
#      'twpq.wjl': 174963,
#      'vnfhb': {'tvmwhq.wfn': 128626},
#      'wcldzp': {'ncq': {'wrtw': {'fcqrwd': 133331}},
#       'twpq': {'fcqrwd': 151811}}},
#     'ccsfws': {'twpq.ppm': 100548},
#     'mccw': 87225,
#     'pbb.zln': 290654,
#     'twzqc.pbz': 147394,
#     'wsvgf': 52983,
#     'wwfgbzqh': {'lmw': {'bgl': {'lmw': {'wmdldvbz': 233655},
#        'rrqjwpm': {'frqqdsr.hbf': 242918,
#         'hjpmqrq': 227581,
#         'hsvnmlp': {'pbb.zln': 264517},
#         'nsch': {'cmsdzh': 7898,
#          'dmpsnhdh.bsq': 233270,
#          'frl': 101256,
#          'jzvh.vdv': 133902,
#          'lmw': {'bnjnc.csp': 69572},
#          'sgjsg': {'tnzpz.tbq': 38856},
#          'wcftvft': 130245},
#         'pbb.zln': 25524,
#         'qlgg': {'frbstg.pzb': 276013},
#         'twpq': {'fhwz.bqb': 136454,
#          'rglp': 94099,
#          'tsrt.cbd': 114026,
#          'zhclpzm.rqf': 26252},
#         'twpq.fms': 67453}},
#       'dncdssn.hdr': 95150,
#       'frqqdsr.hbf': 119653,
#       'hjpmqrq': 97941,
#       'jqthwzj': {'lmw.btl': 128200}},
#      'mfms': {'dmpsnhdh': 274935,
#       'lchwq.dsd': 76547,
#       'pbb.zln': 215701,
#       'rmwtvjt': {'hjpmqrq': 74490}},
#      'pjbjgbcl': {'cjcpwwc.wbf': 231757,
#       'cswvftzs': {'dchqnbns': {'szl.hqs': 94111},
#        'smf': {'dlnsgvl': {'dsz': {'hjpmqrq': 156473}},
#         'zglt': {'frgg.sdp': 295383}}},
#       'jtvtg': {'bftv.rqb': 202254, 'lmw': 58419},
#       'lmw': {'fcqrwd': 8097},
#       'tnctbjr': {'frqqdsr.hbf': 250830,
#        'gzrcqr': {'fnzgsnv': {'hjpmqrq': 117215}}},
#       'tqsrfhdr': {'lmw': 96381}},
#      'qtflzwm': 204154,
#      'vdmjj.htj': 226500,
#      'wzqbwr': {'dmpsnhdh.vnd': 149066,
#       'dpbcgfdr': {'dmpsnhdh': 12909,
#        'jvn': {'vqddrqlq.nfd': 117656, 'vqqvh.swz': 233109},
#        'mnhpr.lpr': 173491,
#        'rfqfjmd.jqq': 222018,
#        'wbbdrpr.hzj': 205077,
#        'wzpbbbhm': {'pbb.zln': 143534}},
#       'swp': {'pbb.zln': 131295},
#       'twpq.gsb': 14495,
#       'zhj': {'pbb.zln': 166268, 'rrqjwpm.blg': 33734}}}},
#    'twpq': {'bppvlwqs': {'hvlhgsw': 195026, 'rrqjwpm': 279259},
#     'bvh': {'lmw': {'pdqnd': 66958}},
#     'rmcdr': {'dmpsnhdh': {'rrqjwpm': {'bnl': {'lmw.mgf': 245600},
#        'lmw': {'hjpmqrq': 73396},
#        'vsntvs.pdv': 7598},
#       'zgjzpbl.vgv': 188474},
#      'grj': 182930,
#      'pmrdhrth': {'rrqjwpm.pjw': 173155, 'smgpzs.qtj': 178530},
#      'qpcqclqh': 119725,
#      'sjgfjz': 77890,
#      'twpq': 142855,
#      'zbmcrvbh': {'fcqrwd': 124201,
#       'hjpmqrq': 135578,
#       'hnztplsp.qlh': 54356,
#       'lmw': {'bbbll': {'dncdssn.hdr': 169940,
#         'pbb.zln': 216888,
#         'tjpmlr.vmf': 248369},
#        'bfgfwlf.wvg': 28362,
#        'dmpndms.fln': 229637,
#        'dncdssn.hdr': 146121,
#        'frqqdsr.hbf': 131039,
#        'hjpmqrq': 152805,
#        'mlz': {'bhfv.fts': 115167}},
#       'pbb.zln': 58350,
#       'qfrvdm': {'pbb.zln': 284564},
#       'rcg': {'sqzjz': {'jrstpcpl.zsq': 116435}},
#       'rwbzjpt.djn': 15267}},
#     'tdn': {'cmg': 143971,
#      'fcqrwd': 133317,
#      'pstpclp': {'hjpmqrq': 267351, 'rrqjwpm.dvl': 86930},
#      'tddv': 133161},
#     'whb.lfb': 2230,
#     'wwtwnvh': {'frqqdsr.hbf': 256584, 'twpq.wrd': 114564}},
#    'vlgsrtm': {'bnl.jzj': 148089,
#     'cjfphsfw.hnd': 119796,
#     'cpw': 197668,
#     'dmpsnhdh': {'lltnrdtv': {'pcvmpz': 179511, 'tbr': 90913},
#      'scthsg': {'rrqjwpm': {'fcqrwd': 188629}}},
#     'fjsglr': {'fcqrwd': 139754, 'pnsjwfzc': {'lmw': 113848}},
#     'lmw': {'dmpsnhdh': 54999,
#      'ffhcf': {'svmwstq.sjj': 40478},
#      'frqqdsr.hbf': 251476,
#      'jpgqspqw': {'hjpmqrq': 22181},
#      'nhfclq.pbh': 198972,
#      'nqmjnvc.fvr': 180380,
#      'pfsjwmbc': {'bcvchw': {'bnl.nwc': 225892}},
#      'rcvccgcd': 213768},
#     'lqgrft': {'rrqjwpm': {'fcqrwd': 54786, 'tthhqjm.ntd': 3053},
#      'twpq': {'bnl': 109355,
#       'lmw': {'lmw': {'pbb.zln': 139640},
#        'lngbszqm': {'mqvq.gsj': 98279, 'rvjd.dvt': 283599}},
#       'mhgqt': {'fcqrwd': 208165},
#       'rrqjwpm.lrm': 301291,
#       'twpq.srp': 271233}},
#     'pltdltrs': 9231,
#     'rmdp': {'bqn': {'hdrgbrpc': 75628},
#      'fcqrwd': 170956,
#      'snnttp.gld': 90954},
#     'rncfff.fll': 109777,
#     'vgjzqjpq': {'bnl': {'pbb.zln': 25911}, 'wpfw': {'bzll.ltc': 247784}},
#     'ztnqnfnq': {'dtpzsrfc': {'bhgwj': 142652}, 'srgzhp.nlr': 214055}}}}}

# %%
        if type(tree[key]) is dict:
            for sub in tree[key].keys():
                if type(tree[key][sub]) is int:
                    dirDict[key] += tree[key][sub]
                else:
                    subDict = navigateTree({sub: tree[key][sub]})
                    dirDict[key] += subDict[sub]
                    dirDict.update(subDict)

# %%
dirDict
# Out:
# {'/': 31196568,
#  'bnl': 25911,
#  'dhw': 237421,
#  'dmpsnhdh': 459053,
#  'chf': 573029,
#  'zfgznbz': 350983,
#  'mjpbhjm': 1375812,
#  'crf': 497521,
#  'hqnj': 339702,
#  'lmw': 521518,
#  'zwhpwp': 141133,
#  'dvv': 216597,
#  'vgbqbrst': 1177154,
#  'jbdtpnw': 27543,
#  'rflp': 221045,
#  'twpq': 1411562,
#  'rlbsdj': 56078,
#  'fnpwwhtj': 514966,
#  'cgp': 514966,
#  'bfbv': 92667,
#  'rrqjwpm': 57839,
#  'sngm': 2215519,
#  'glwr': 144719,
#  'lqd': 925297,
#  'jnjqmvg': 104947,
#  'szn': 197974,
#  'fcnqg': 769565,
#  'jvwtm': 8509877,
#  'llhp': 180255,
#  'mnsbh': 267627,
#  'mpplsfjp': 476965,
#  'tlr': 1219467,
#  'vcsngm': 36434,
#  'wndmt': 1183033,
#  'fvmtfcqd': 237025,
#  'nvdb': 338644,
#  'nwqqgl': 337354,
#  'cljbrh': 133820,
#  'sbspgnpm': 270010,
#  'hbchdjjp': 301016,
#  'wbgcsw': 3609909,
#  'fbbr': 84414,
#  'mzfrdl': 625824,
#  'cjdptqgh': 159918,
#  'hwdnrqns': 254432,
#  'prq': 75827,
#  'tqgrdz': 251475,
#  'ztrnq': 387873,
#  'bqq': 202201,
#  'ctnlpgt': 269484,
#  'hbqm': 117203,
#  'zqmjwsgz': 146194,
#  'zwwphs': 209587,
#  'zjmldjdh': 1030017,
#  'cdq': 289173,
#  'mdclfbs': 404395,
#  'hpdgt': 107421,
#  'tfc': 204406,
#  'ldztz': 978231,
#  'lbqgz': 171931,
#  'znrnj': 153738,
#  'lmmw': 1507116,
#  'bqqnsfdj': 1008403,
#  'sfj': 156532,
#  'nqw': 59928,
#  'tlnbvhdl': 183301,
#  'rlpcqtzg': 258638,
#  'wthvqw': 224501,
#  'zpdnprb': 13545698,
#  'pnzmp': 236287,
#  'btbtlrs': 107651,
#  'ffg': 57918,
#  'jljlwpsv': 346425,
#  'bftw': 1561114,
#  'brl': 297937,
#  'vnfhb': 128626,
#  'wcldzp': 285142,
#  'ncq': 133331,
#  'wrtw': 133331,
#  'ccsfws': 100548,
#  'wwfgbzqh': 4696415,
#  'bgl': 2423491,
#  'hsvnmlp': 264517,
#  'nsch': 714999,
#  'sgjsg': 38856,
#  'qlgg': 276013,
#  'jqthwzj': 128200,
#  'mfms': 641673,
#  'rmwtvjt': 74490,
#  'pjbjgbcl': 1510920,
#  'cswvftzs': 545967,
#  'dchqnbns': 94111,
#  'smf': 451856,
#  'dlnsgvl': 156473,
#  'dsz': 156473,
#  'zglt': 295383,
#  'jtvtg': 260673,
#  'tnctbjr': 368045,
#  'gzrcqr': 117215,
#  'fnzgsnv': 117215,
#  'tqsrfhdr': 96381,
#  'wzqbwr': 1602652,
#  'dpbcgfdr': 1107794,
#  'jvn': 350765,
#  'wzpbbbhm': 143534,
#  'swp': 131295,
#  'zhj': 200002,
#  'bppvlwqs': 474285,
#  'bvh': 66958,
#  'rmcdr': 3617232,
#  'pmrdhrth': 351685,
#  'zbmcrvbh': 2227079,
#  'bbbll': 635197,
#  'mlz': 115167,
#  'qfrvdm': 284564,
#  'rcg': 116435,
#  'sqzjz': 116435,
#  'tdn': 764730,
#  'pstpclp': 354281,
#  'wwtwnvh': 371148,
#  'vlgsrtm': 4922703,
#  'lltnrdtv': 270424,
#  'scthsg': 188629,
#  'fjsglr': 253602,
#  'pnsjwfzc': 113848,
#  'ffhcf': 40478,
#  'jpgqspqw': 22181,
#  'pfsjwmbc': 225892,
#  'bcvchw': 225892,
#  'lqgrft': 1469401,
#  'lngbszqm': 381878,
#  'mhgqt': 208165,
#  'rmdp': 337538,
#  'bqn': 75628,
#  'vgjzqjpq': 273695,
#  'wpfw': 247784,
#  'ztnqnfnq': 356707,
#  'dtpzsrfc': 142652}

# %%
dirDict[key] = 0

# %%
type(tree[key])
# Out:
# dict

# %%
sub = 'a'

# %%
type(tree[key][sub])
# Out:
# dict

# %%
tree2 = {sub: tree[key][sub]}

# %%
log = '''$ cd /
$ ls
dir a
14848514 b.txt
8504156 c.dat
dir d
$ cd a
$ ls
dir e
29116 f
2557 g
62596 h.lst
$ cd e
$ ls
584 i
$ cd ..
$ cd ..
$ cd d
$ ls
4060174 j
8033020 d.log
5626152 d.ext
7214296 k'''.split('\n')
